# %% [markdown]
# #### EDA and fillna with ROLLING MEAN and BACKFILL

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal     import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller

from datetime import datetime,timedelta
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing,Holt
from statsmodels.tsa.stattools         import  pacf
from statsmodels.tsa.stattools         import  acf
from statsmodels.graphics.tsaplots     import  plot_pacf
from statsmodels.graphics.tsaplots     import  plot_acf
from statsmodels.graphics.gofplots     import qqplot
from statsmodels.tsa.arima_model       import  ARMA, ARIMA
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import tensorflow as tf
# Out:
# C:\Users\csnaik\anaconda3\envs\tf_rani\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
 df = pd.read_excel('Price_BeetRoot_ClusterBeans.xlsx',parse_dates =["Date"], index_col ='Date')
df.head(2)
# Out:
#             Arrivals(Qtls)  Maximum  Minimum  Model      Purchase by
# Date
# 2017-01-01               7    800.0      800    800  Private Traders
# 2017-01-02               2    800.0      800    800  Private Traders

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 583 entries, 2017-01-01 to 2019-12-30
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Arrivals(Qtls)  583 non-null    int64
#  1   Maximum         582 non-null    float64
#  2   Minimum         583 non-null    int64
#  3   Model           583 non-null    int64
#  4   Purchase by     583 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 27.3+ KB

# %%
df.isnull().sum()
# Out:
# Arrivals(Qtls)    0
# Maximum           1
# Minimum           0
# Model             0
# Purchase by       0
# dtype: int64

# %%
df.describe()
# Out:
#        Arrivals(Qtls)      Maximum      Minimum         Model
# count      583.000000   582.000000   583.000000    583.000000
# mean         4.962264  1677.955326  1636.620926   1787.205832
# std          3.215932   810.050961   776.214981   3338.314442
# min          1.000000   300.000000   200.000000    200.000000
# 25%          3.000000  1000.000000  1000.000000   1000.000000
# 50%          5.000000  1600.000000  1600.000000   1600.000000
# 75%          6.000000  2000.000000  2000.000000   2000.000000
# max         20.000000  6020.000000  4200.000000  80021.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
dt = pd.date_range(start ='01-01-2017', end ='30-12-2019', freq ='D' )
dt
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2019-12-21', '2019-12-22', '2019-12-23', '2019-12-24',
#                '2019-12-25', '2019-12-26', '2019-12-27', '2019-12-28',
#                '2019-12-29', '2019-12-30'],
#               dtype='datetime64[ns]', length=1094, freq='D')

# %%
df1 = pd.DataFrame(columns=['Arrivals(Qtls)'],data=df, index = dt)
df1.head(10)
# Out:
#             Arrivals(Qtls)
# 2017-01-01             7.0
# 2017-01-02             2.0
# 2017-01-03             9.0
# 2017-01-04             9.0
# 2017-01-05             6.0
# 2017-01-06             6.0
# 2017-01-07             5.0
# 2017-01-08             7.0
# 2017-01-09             6.0
# 2017-01-10             2.0

# %%
df1.isnull().sum()
# Out:
# Arrivals(Qtls)    511
# dtype: int64

# %%
df1 = df1.fillna(df1.rolling(22,min_periods=1).mean())

# %%
df1.isnull().sum()
# Out:
# Arrivals(Qtls)    0
# dtype: int64

# %% [markdown]
# #### the null values are filled after 22 datapoints

# %%
df1.value_counts()
# Out:
# Arrivals(Qtls)
# 5.000000          123
# 2.000000          121
# 3.000000          100
# 4.000000           70
# 6.000000           58
#                  ...
# 5.733333            1
# 5.722222            1
# 3.384615            1
# 5.705882            1
# 5.200000            1
# Length: 220, dtype: int64

# %%
df1['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
df1.describe().plot.bar(figsize=(10,5))
plt.show()

# %%
plot_acf(df1, lags =25)
plt.show()

# %%
plot_pacf(df1,lags =25)
plt.show()

# %% [markdown]
# #### The plot for 200 datapoints ...~ 7 months

# %%
plt.figure(figsize=(8,4))
results = seasonal_decompose(df1['Arrivals(Qtls)'].iloc[800:1000])
results.plot();

# %% [markdown]
# #### DICKEY FULLER TEST for STATIONARITY

# %%
observations= df1.values
test_result = adfuller(observations)

# %%
print('ADF Statistic: %f' % test_result[0])
print('p-value: %f' % test_result[1])
print('Critical Values:')
for key, value in test_result[4].items():
	print('\t%s: %.5f' % (key, value))
# Out:
# ADF Statistic: -3.361879
# p-value: 0.012329
# Critical Values:
# 	1%: -3.43641
# 	5%: -2.86421
# 	10%: -2.56819

# %% [markdown]
# ##### USING AUTO TIMESERIES for selection of best model

# %%
#! pip install auto-ts

# %%
from auto_ts import auto_timeseries
# Out:
# Importing plotly failed. Interactive plots will not work.
# Imported auto_timeseries version:0.0.64. Call by using:
# model = auto_timeseries(score_type='rmse',
#         time_interval='M', non_seasonal_pdq=None, seasonality=False,
#         seasonal_period=12, model_type=['best'], verbose=2, dask_xgboost_flag=0)
# model.fit(traindata, ts_column,target)
# model.predict(testdata, model='best')

# %%
df.head(2)
# Out:
#             Arrivals(Qtls)  Maximum  Minimum  Model      Purchase by
# Date
# 2017-01-01               7    800.0      800    800  Private Traders
# 2017-01-02               2    800.0      800    800  Private Traders

# %%
df.tail(2)
# Out:
#             Arrivals(Qtls)  Maximum  Minimum  Model      Purchase by
# Date
# 2019-12-28               3   2000.0     1800   1900  Private Traders
# 2019-12-30               5   3000.0     3000   3000  Private Traders

# %% [markdown]
# ### Split the time series data into training and testing sets

# %%
train_end = datetime(2018,12,30)
test_end = datetime(2019,12,30)

# %%
train = df1[:train_end]
test = df1[train_end + timedelta(days =1): test_end]

# %%
train.shape,test.shape
# Out:
# ((729, 1), (365, 1))

# %%
train['Arrivals(Qtls)'].plot(figsize=(10,6))
test['Arrivals(Qtls)'].plot(figsize=(10,6))
plt.show()

# %%
model = auto_timeseries(forecast_period =365,score_type='rmse',time_interval='D', non_seasonal_pdq=None, seasonality=False,
         model_type=['best'])

# %%
#### reshape train and test for model input

# %%
train.reset_index(inplace=True)
test.reset_index(inplace= True)

# %%
train.head(), test.head()
# Out:
# (       index  Arrivals(Qtls)
#  0 2017-01-01             7.0
#  1 2017-01-02             2.0
#  2 2017-01-03             9.0
#  3 2017-01-04             9.0
#  4 2017-01-05             6.0,
#         index  Arrivals(Qtls)
#  0 2018-12-31        5.000000
#  1 2019-01-01        4.333333
#  2 2019-01-02        6.000000
#  3 2019-01-03        4.500000
#  4 2019-01-04        4.111111)

# %%
model.fit(traindata = train, ts_column ='index', target ='Arrivals(Qtls)')
# Out:
# Start of Fit.....
#     Target variable given as = Arrivals(Qtls)
# Start of loading of data.....
#     Inputs: ts_column = index, sep = ,, target = ['Arrivals(Qtls)']
#     Using given input: pandas dataframe...
#     index column exists in given train data...
#     train data shape = (729, 1)
# Alert: Could not detect strf_time_format of index. Provide strf_time format during "setup" for better results.
#
# Running Augmented Dickey-Fuller test with paramters:
#     maxlag: 31 regression: c autolag: BIC
# Data is already stationary
# There is no differencing needed in this datasets for VAR model
# No time series plot since verbose = 0. Continuing
# Time Interval is given as D
#     Correct Time interval given as a valid Pandas date-range frequency...
# WARNING: Running best models will take time... Be Patient...
#
#
# ==================================================
# Building Prophet Model
# ==================================================
#
#
#
# Running Facebook Prophet Model...
#   Starting Prophet Fit
#       No seasonality assumed since seasonality flag is set to False
#   Starting Prophet Cross Validation
# Lowering forecast period to 121 to enable cross_validation
# Max. iterations using expanding window cross validation = 5
#
# Fold Number: 1 --> Train Shape: 124 Test Shape: 121
#     RMSE = 3.86
#     Std Deviation of actuals = 1.93
#     Normalized RMSE (as pct of std dev) = 200%
# Cross Validation window: 1 completed
#
# Fold Number: 2 --> Train Shape: 245 Test Shape: 121
#     RMSE = 3.95
#     Std Deviation of actuals = 2.70
#     Normalized RMSE (as pct of std dev) = 147%
# Cross Validation window: 2 completed
#
# Fold Number: 3 --> Train Shape: 366 Test Shape: 121
#     RMSE = 5.70
#     Std Deviation of actuals = 3.55
#     Normalized RMSE (as pct of std dev) = 160%
# Cross Validation window: 3 completed
#
# Fold Number: 4 --> Train Shape: 487 Test Shape: 121
#     RMSE = 5.96
#     Std Deviation of actuals = 2.57
#     Normalized RMSE (as pct of std dev) = 232%
# Cross Validation window: 4 completed
#
# Fold Number: 5 --> Train Shape: 608 Test Shape: 121
#     RMSE = 2.28
#     Std Deviation of actuals = 1.98
#     Normalized RMSE (as pct of std dev) = 115%
# Cross Validation window: 5 completed
#
# -------------------------------------------
# Model Cross Validation Results:
# -------------------------------------------
#     MAE (Mean Absolute Error = 3.64
#     MSE (Mean Squared Error = 20.74
#     MAPE (Mean Absolute Percent Error) = 84%
#     RMSE (Root Mean Squared Error) = 4.5546
#     Normalized RMSE (MinMax) = 24%
#     Normalized RMSE (as Std Dev of Actuals)= 161%
# Time Taken = 32 seconds
#   End of Prophet Fit
#
#
# ==================================================
# Building Auto SARIMAX Model
# ==================================================
#
#
#
# Running Auto SARIMAX Model...
# Lowering forecast period to 121 to enable cross_validation
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=829.942, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=654.933, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=755.187, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=622.312, Time=0.13 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=613.389, Time=0.17 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=598.089, Time=0.66 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=596.755, Time=0.35 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=594.756, Time=0.20 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=596.755, Time=0.34 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=713.868, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=598.703, Time=0.36 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=589.893, Time=0.85 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=594.226, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=593.629, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=591.522, Time=0.70 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=591.534, Time=0.56 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=594.044, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=592.925, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=592.029, Time=0.17 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=593.512, Time=1.08 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 6.125 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1221.350, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1146.036, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1080.082, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1219.357, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1081.631, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1081.639, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1083.630, Time=0.25 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1078.353, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1079.875, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1079.881, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1144.043, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1081.874, Time=0.25 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.486 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1832.753, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1729.957, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1622.465, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1830.758, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1623.652, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1623.546, Time=0.23 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1624.840, Time=0.64 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1620.652, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1621.834, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1621.728, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1727.962, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1623.018, Time=0.32 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.100 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2543.943, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2390.257, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2265.439, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2541.955, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2266.252, Time=0.26 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2266.293, Time=0.60 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2264.397, Time=0.57 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2266.371, Time=1.06 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2266.369, Time=1.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2268.163, Time=0.70 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2268.172, Time=0.38 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2271.424, Time=2.17 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2262.572, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=2264.458, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2264.417, Time=0.12 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2264.544, Time=0.67 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=2264.542, Time=0.46 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2263.623, Time=0.08 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=2266.334, Time=0.22 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2266.343, Time=0.16 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=inf, Time=1.93 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 11.323 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3182.138, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2967.233, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2817.370, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3180.142, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2816.628, Time=0.29 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2817.603, Time=0.42 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2815.309, Time=0.62 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2816.891, Time=0.28 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2816.751, Time=1.31 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2816.775, Time=1.39 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2817.637, Time=0.63 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2821.009, Time=1.60 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2813.372, Time=0.32 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=2814.953, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2814.690, Time=0.19 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2814.814, Time=0.89 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=2814.838, Time=0.75 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2815.434, Time=0.09 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=2815.699, Time=0.26 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2815.664, Time=0.17 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=2819.072, Time=1.14 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 10.975 seconds
#
# SARIMAX RMSE (all folds): 3.6980
# SARIMAX Norm RMSE (all folds): 131%
#
#
# -------------------------------------------
# Model Cross Validation Results:
# -------------------------------------------
#     MAE (Mean Absolute Error = 3.00
#     MSE (Mean Squared Error = 14.48
#     MAPE (Mean Absolute Percent Error) = 67%
#     RMSE (Root Mean Squared Error) = 3.8056
#     Normalized RMSE (MinMax) = 20%
#     Normalized RMSE (as Std Dev of Actuals)= 135%
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3789.585, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3528.586, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3340.558, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3787.586, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3337.495, Time=0.22 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3339.077, Time=0.46 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3337.977, Time=0.70 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3337.815, Time=0.28 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3447.742, Time=0.20 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3338.396, Time=1.28 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3335.507, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3338.568, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3526.587, Time=0.10 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3337.088, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3335.987, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3335.827, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=3445.743, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=3336.408, Time=1.13 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 5.888 seconds
# Refitting data with previously found best parameters
#     Best aic metric = 3329.7
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:         Arrivals(Qtls)   No. Observations:                  729
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -1659.841
# Date:                Sun, 01 May 2022   AIC                           3329.681
# Time:                        12:39:38   BIC                           3352.619
# Sample:                    01-01-2017   HQIC                          3338.533
#                          - 12-30-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0137      0.039     -0.348      0.728      -0.091       0.063
# drift       1.961e-05    9.2e-05      0.213      0.831      -0.000       0.000
# ar.L1         -0.1406      0.037     -3.805      0.000      -0.213      -0.068
# ma.L1         -0.8133      0.021    -37.996      0.000      -0.855      -0.771
# sigma2         6.0129      0.199     30.240      0.000       5.623       6.403
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.55   Jarque-Bera (JB):              1337.54
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                             1.48
# Prob(H) (two-sided):                  0.91   Kurtosis:                         8.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# ==================================================
# Building VAR Model - best suited for small datasets < 1000 rows and < 10 columns
# ==================================================
#
#
#
# No VAR model created since no explanatory variables given in data set
#
#
# ==================================================
# Building ML Model
# ==================================================
#
#
#
# Creating 2 lagged variables for Machine Learning model...
#     You have set lag = 3 in auto_timeseries setup to feed prior targets. You cannot set lags > 10 ...
# ### Be careful setting dask_xgboost_flag to True since dask is unstable and doesn't work sometime's ###
#
# ########### Single-Label Regression Model Tuning and Training Started ####
#
# Fitting ML model
#     11 variables used in training ML model = ['Arrivals(Qtls)(t-1)', 'index_hour', 'index_minute', 'index_dayofweek', 'index_quarter', 'index_month', 'index_year', 'index_dayofyear', 'index_dayofmonth', 'index_weekofyear', 'index_weekend']
#     Forecast period too high. Cutting by 90% to 72 to enable cross_validation
#
# Running Cross Validation using XGBoost model..
#     Max. iterations using expanding window cross validation = 2
# train fold shape (655, 11), test fold shape = (73, 11)
# ### Number of booster rounds = 250 for XGBoost which can be set during setup ####
#     Hyper Param Tuning XGBoost with CPU parameters. This will take time. Please be patient...
# Cross-validated Score = 2.453 in num rounds = 249
# Time taken for Hyper Param tuning of XGBoost (in minutes) = 0.1
# Top 10 features:
# ['Arrivals(Qtls)(t-1)', 'index_year', 'index_weekofyear', 'index_dayofyear', 'index_month', 'index_quarter', 'index_dayofweek', 'index_dayofmonth', 'index_weekend']
#     Time taken for training XGBoost on entire train data (in minutes) = 0.1
# Returning the following:
#     Model = <xgboost.core.Booster object at 0x0000024764407700>
#     Scaler = Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('simpleimputer',
#                                                   SimpleImputer(),
#                                                   ['Arrivals(Qtls)(t-1)',
#                                                    'index_hour', 'index_minute',
#                                                    'index_dayofweek',
#                                                    'index_quarter',
#                                                    'index_month', 'index_year',
#                                                    'index_dayofyear',
#                                                    'index_dayofmonth',
#                                                    'index_weekofyear',
#                                                    'index_weekend'])])),
#                 ('maxabsscaler', MaxAbsScaler())])
#     (3) sample predictions:[5.2322598 5.3366656 4.7235136]
# XGBoost model tuning completed
# Target = Arrivals(Qtls)...CV results:
#     RMSE = 2.73
#     Std Deviation of actuals = 1.78
#     Normalized RMSE (as pct of std dev) = 153%
#
# Fitting model on entire train set. Please be patient...
#     Time taken to train model (in seconds) = 1
#
# Best Model is: ML
#     Best Model (Mean CV) Score: 2.73
#
#
# --------------------------------------------------
# Total time taken: 89 seconds.
# --------------------------------------------------
#
#
# Leaderboard with best model on top of list:
#             name      rmse
# 3            ML  2.730091
# 1  auto_SARIMAX  3.697971
# 0       Prophet  4.350920
# 2           VAR       inf

# %%
future_pred = model.predict(testdata = test, model = 'best')
# Out:
# Predicting using test dataframe shape = (365, 2) for ML model
# For large datasets: ML predictions will take time since it has to predict each row and use that for future predictions...
#     Using given input: pandas dataframe...
#     Alert: No strf_time_format given for index. Provide strf_time format during "setup" for better results.
# ML predictions completed

# %%
future_pred.values
# Out:
# array([[3.14149857,        nan,        nan,        nan],
#        [3.27654862,        nan,        nan,        nan],
#        [3.51442838,        nan,        nan,        nan],
#        ...,
#        [3.31207561,        nan,        nan,        nan],
#        [3.23289776,        nan,        nan,        nan],
#        [3.16994715,        nan,        nan,        nan]])

# %%
future_pred.head(2)
# Out:
#             Arrivals(Qtls)  mean_se  mean_ci_lower  mean_ci_upper
# index
# 2018-12-31        3.141499      NaN            NaN            NaN
# 2019-01-01        3.276549      NaN            NaN            NaN

# %%
test['ypred']=future_pred['Arrivals(Qtls)'].values

# %%
test.head(10)
# Out:
#        index  Arrivals(Qtls)     ypred
# 0 2018-12-31        5.000000  3.141499
# 1 2019-01-01        4.333333  3.276549
# 2 2019-01-02        6.000000  3.514428
# 3 2019-01-03        4.500000  4.430110
# 4 2019-01-04        4.111111  4.517567
# 5 2019-01-05        4.111111  4.418027
# 6 2019-01-06        4.111111  3.602107
# 7 2019-01-07        4.111111  3.281844
# 8 2019-01-08        4.000000  3.251866
# 9 2019-01-09        4.000000  3.153696

# %% [markdown]
# https://www.youtube.com/watch?v=YVQzFCPkgt4

# %%
test['Arrivals(Qtls)'].plot(figsize=(10,6))
test['ypred'].plot(figsize=(10,6))
plt.show()

# %%
train.set_index('index', inplace = True)
train.head(2)
# Out:
#             Arrivals(Qtls)
# index
# 2017-01-01             7.0
# 2017-01-02             2.0

# %%
plt.plot(train['Arrivals(Qtls)'], label='Train')
plt.show()

# %%
test.set_index('index', inplace = True)
test.head(2)
# Out:
#             Arrivals(Qtls)     ypred
# index
# 2018-12-31        5.000000  3.141499
# 2019-01-01        4.333333  3.276549

# %%
plt.plot(train['Arrivals(Qtls)'], label='Train')
plt.plot(test['Arrivals(Qtls)'], label='Test')
plt.plot(test['ypred'], label='Prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['Arrivals(Qtls)'],test['ypred']))
print("ROOT MEAN SQAURED ERROR (RMSE) :",rmse)
# Out:
# ROOT MEAN SQAURED ERROR (RMSE) : 2.785564961049483
