# %% [markdown]
# #### EDA and fillna with ROLLING MEAN and BACKFILL

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal     import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller

from datetime import datetime,timedelta
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing,Holt
from statsmodels.tsa.stattools         import  pacf
from statsmodels.tsa.stattools         import  acf
from statsmodels.graphics.tsaplots     import  plot_pacf
from statsmodels.graphics.tsaplots     import  plot_acf
from statsmodels.graphics.gofplots     import qqplot
from statsmodels.tsa.arima_model       import  ARMA, ARIMA
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import tensorflow as tf
# Out:
# C:\Users\csnaik\anaconda3\envs\tf_rani\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
 df = pd.read_excel('Sample Commodities_Vegetables_Hyderabad_Market.xlsx',
                    sheet_name="Tomato",parse_dates =["Date"], index_col ='Date')
df.head(2)
# Out:
#            Variety Name  Arrivals(Qtls)  Maximum  Minimum  Model  \
# Date
# 2017-04-25       Tomato             232      800      600    700
# 2017-04-28       Tomato             222      800      600    700
#
#                 Purchase by
# Date
# 2017-04-25  Private Traders
# 2017-04-28  Private Traders

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 749 entries, 2017-04-25 to 2019-12-31
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Variety Name    749 non-null    object
#  1   Arrivals(Qtls)  749 non-null    int64
#  2   Maximum         749 non-null    int64
#  3   Minimum         749 non-null    int64
#  4   Model           749 non-null    int64
#  5   Purchase by     749 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 41.0+ KB

# %%
df.isnull().sum()
# Out:
# Variety Name      0
# Arrivals(Qtls)    0
# Maximum           0
# Minimum           0
# Model             0
# Purchase by       0
# dtype: int64

# %%
df.describe()
# Out:
#        Arrivals(Qtls)       Maximum       Minimum         Model
# count      749.000000    749.000000    749.000000    749.000000
# mean       180.225634   1856.141522   1369.639519   1671.695594
# std        104.799725   1492.903780   1370.141686   2237.955566
# min          7.000000     80.000000    100.000000    100.000000
# 25%        130.000000    800.000000    600.000000    700.000000
# 50%        167.000000   1200.000000    800.000000   1100.000000
# 75%        215.000000   2600.000000   2000.000000   2200.000000
# max       2017.000000  20000.000000  22400.000000  44400.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
dt = pd.date_range(start ='25-04-2017', end ='30-12-2019', freq ='D' )
dt
# Out:
# DatetimeIndex(['2017-04-25', '2017-04-26', '2017-04-27', '2017-04-28',
#                '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#                '2017-05-03', '2017-05-04',
#                ...
#                '2019-12-21', '2019-12-22', '2019-12-23', '2019-12-24',
#                '2019-12-25', '2019-12-26', '2019-12-27', '2019-12-28',
#                '2019-12-29', '2019-12-30'],
#               dtype='datetime64[ns]', length=980, freq='D')

# %%
df1 = pd.DataFrame(columns=['Arrivals(Qtls)'],data=df, index = dt)
df1.head(10)
# Out:
#             Arrivals(Qtls)
# 2017-04-25           232.0
# 2017-04-26             NaN
# 2017-04-27             NaN
# 2017-04-28           222.0
# 2017-04-29           200.0
# 2017-04-30             NaN
# 2017-05-01           217.0
# 2017-05-02           125.0
# 2017-05-03           267.0
# 2017-05-04             NaN

# %%
df1.isnull().sum()
# Out:
# Arrivals(Qtls)    232
# dtype: int64

# %%
df1 = df1.fillna(df1.rolling(22,min_periods=1).mean())

# %%
df1.isnull().sum()
# Out:
# Arrivals(Qtls)    0
# dtype: int64

# %% [markdown]
# #### the null values are filled after 22 datapoints

# %%
df1.value_counts()
# Out:
# Arrivals(Qtls)
# 150.000000        18
# 175.000000        14
# 162.000000        14
# 190.000000        13
# 157.000000        13
#                   ..
# 174.052632         1
# 174.300000         1
# 174.388889         1
# 174.789474         1
# 2017.000000        1
# Length: 351, dtype: int64

# %%
df1['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
df1.boxplot()
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 980 entries, 2017-04-25 to 2019-12-30
# Freq: D
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Arrivals(Qtls)  980 non-null    float64
# dtypes: float64(1)
# memory usage: 15.3 KB

# %%
df1.describe().plot.bar(figsize=(10,5))
plt.show()

# %%
q1= df1.quantile(0.25)
q3 = df1.quantile(0.75)
qmax= df1.quantile(0.90)
q1,q3,qmax
# Out:
# (Arrivals(Qtls)    134.5
#  Name: 0.25, dtype: float64,
#  Arrivals(Qtls)    215.428571
#  Name: 0.75, dtype: float64,
#  Arrivals(Qtls)    260.0
#  Name: 0.9, dtype: float64)

# %%
for i in range(len(df1)):
    if df1['Arrivals(Qtls)'][i] >=1000.0:
        print(df1['Arrivals(Qtls)'][i])
        df1['Arrivals(Qtls)'][i] = qmax
# Out:
# 1000.0
# 1000.0
# 1000.0
# 2017.0

# %%
df1.describe()
# Out:
#        Arrivals(Qtls)
# count      980.000000
# mean       176.710305
# std         60.031400
# min          7.000000
# 25%        134.500000
# 50%        172.000000
# 75%        215.428571
# max        345.000000

# %%
df1.describe().plot.bar(figsize=(10,5))
plt.show()

# %%
plot_acf(df1, lags =25)
plt.show()

# %%
plot_pacf(df1,lags =25)
plt.show()

# %% [markdown]
# #### The plot for 200 datapoints ...~ 7 months

# %%
plt.figure(figsize=(8,4))
results = seasonal_decompose(df1['Arrivals(Qtls)'].iloc[800:1000])
results.plot();

# %% [markdown]
# #### DICKEY FULLER TEST for STATIONARITY

# %%
observations= df1.values
test_result = adfuller(observations)

# %%
print('ADF Statistic: %f' % test_result[0])
print('p-value: %f' % test_result[1])
print('Critical Values:')
for key, value in test_result[4].items():
	print('\t%s: %.5f' % (key, value))
# Out:
# ADF Statistic: -3.050476
# p-value: 0.030442
# Critical Values:
# 	1%: -3.43711
# 	5%: -2.86452
# 	10%: -2.56836

# %% [markdown]
# ##### USING AUTO TIMESERIES for selection of best model

# %%
#! pip install auto-ts

# %%
from auto_ts import auto_timeseries
# Out:
# Importing plotly failed. Interactive plots will not work.
# Imported auto_timeseries version:0.0.64. Call by using:
# model = auto_timeseries(score_type='rmse',
#         time_interval='M', non_seasonal_pdq=None, seasonality=False,
#         seasonal_period=12, model_type=['best'], verbose=2, dask_xgboost_flag=0)
# model.fit(traindata, ts_column,target)
# model.predict(testdata, model='best')

# %%
df.head(2)
# Out:
#            Variety Name  Arrivals(Qtls)  Maximum  Minimum  Model  \
# Date
# 2017-04-25       Tomato             232      800      600    700
# 2017-04-28       Tomato             222      800      600    700
#
#                 Purchase by
# Date
# 2017-04-25  Private Traders
# 2017-04-28  Private Traders

# %%
df.tail(2)
# Out:
#            Variety Name  Arrivals(Qtls)  Maximum  Minimum  Model  \
# Date
# 2019-12-30       Tomato             227      600      400    500
# 2019-12-31       Tomato             190      800      600    700
#
#                 Purchase by
# Date
# 2019-12-30  Private Traders
# 2019-12-31  Private Traders

# %% [markdown]
# ### Split the time series data into training and testing sets

# %%
train_end = datetime(2018,12,30)
test_end = datetime(2019,12,30)

# %%
train = df1[:train_end]
test = df1[train_end + timedelta(days =1): test_end]

# %%
train.shape,test.shape
# Out:
# ((615, 1), (365, 1))

# %%
train['Arrivals(Qtls)'].plot(figsize=(10,6))
test['Arrivals(Qtls)'].plot(figsize=(10,6))
plt.show()

# %%
model = auto_timeseries(forecast_period =365,score_type='rmse',time_interval='D', non_seasonal_pdq=None, seasonality=False,
         model_type=['best'])

# %%
#### reshape train and test for model input

# %%
train.reset_index(inplace=True)
test.reset_index(inplace= True)

# %%
train.head(), test.head()
# Out:
# (       index  Arrivals(Qtls)
#  0 2017-04-25           232.0
#  1 2017-04-26           232.0
#  2 2017-04-27           232.0
#  3 2017-04-28           222.0
#  4 2017-04-29           200.0,
#         index  Arrivals(Qtls)
#  0 2018-12-31      187.000000
#  1 2019-01-01      142.000000
#  2 2019-01-02      122.000000
#  3 2019-01-03      177.000000
#  4 2019-01-04      175.888889)

# %%
model.fit(traindata = train, ts_column ='index', target ='Arrivals(Qtls)')
# Out:
# Start of Fit.....
#     Target variable given as = Arrivals(Qtls)
# Start of loading of data.....
#     Inputs: ts_column = index, sep = ,, target = ['Arrivals(Qtls)']
#     Using given input: pandas dataframe...
#     index column exists in given train data...
#     train data shape = (615, 1)
# Alert: Could not detect strf_time_format of index. Provide strf_time format during "setup" for better results.
#
# Running Augmented Dickey-Fuller test with paramters:
#     maxlag: 31 regression: c autolag: BIC
# Data is already stationary
# There is no differencing needed in this datasets for VAR model
# No time series plot since verbose = 0. Continuing
# Time Interval is given as D
#     Correct Time interval given as a valid Pandas date-range frequency...
# WARNING: Running best models will take time... Be Patient...
#
#
# ==================================================
# Building Prophet Model
# ==================================================
#
#
#
# Running Facebook Prophet Model...
#   Starting Prophet Fit
#       No seasonality assumed since seasonality flag is set to False
#   Starting Prophet Cross Validation
# Lowering forecast period to 102 to enable cross_validation
# Max. iterations using expanding window cross validation = 5
#
# Fold Number: 1 --> Train Shape: 105 Test Shape: 102
#     RMSE = 210.31
#     Std Deviation of actuals = 57.36
#     Normalized RMSE (as pct of std dev) = 367%
# Cross Validation window: 1 completed
#
# Fold Number: 2 --> Train Shape: 207 Test Shape: 102
#     RMSE = 124.17
#     Std Deviation of actuals = 72.69
#     Normalized RMSE (as pct of std dev) = 171%
# Cross Validation window: 2 completed
#
# Fold Number: 3 --> Train Shape: 309 Test Shape: 102
#     RMSE = 146.66
#     Std Deviation of actuals = 44.14
#     Normalized RMSE (as pct of std dev) = 332%
# Cross Validation window: 3 completed
#
# Fold Number: 4 --> Train Shape: 411 Test Shape: 102
#     RMSE = 75.87
#     Std Deviation of actuals = 33.62
#     Normalized RMSE (as pct of std dev) = 226%
# Cross Validation window: 4 completed
#
# Fold Number: 5 --> Train Shape: 513 Test Shape: 102
#     RMSE = 57.41
#     Std Deviation of actuals = 31.27
#     Normalized RMSE (as pct of std dev) = 184%
# Cross Validation window: 5 completed
#
# -------------------------------------------
# Model Cross Validation Results:
# -------------------------------------------
#     MAE (Mean Absolute Error = 110.69
#     MSE (Mean Squared Error = 18041.77
#     MAPE (Mean Absolute Percent Error) = 71%
#     RMSE (Root Mean Squared Error) = 134.3197
#     Normalized RMSE (MinMax) = 40%
#     Normalized RMSE (as Std Dev of Actuals)= 219%
# Time Taken = 23 seconds
#   End of Prophet Fit
#
#
# ==================================================
# Building Auto SARIMAX Model
# ==================================================
#
#
#
# Running Auto SARIMAX Model...
# Lowering forecast period to 102 to enable cross_validation
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1031.287, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1006.219, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1005.997, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1029.476, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1006.919, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1007.498, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1008.821, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1004.991, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1005.643, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1006.283, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1004.755, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1005.651, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1006.990, Time=0.10 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 1.435 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2153.252, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2122.048, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2107.637, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2151.281, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2107.996, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2108.317, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2108.837, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2105.866, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2106.317, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=2106.607, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2120.119, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2107.105, Time=0.08 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.117 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3247.918, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3198.482, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3172.999, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3245.924, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3172.045, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3172.761, Time=0.23 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3172.392, Time=0.39 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3172.642, Time=0.18 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3187.296, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3174.331, Time=0.50 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3170.107, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3171.038, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3196.491, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3170.840, Time=0.16 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3170.479, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3170.697, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=3185.313, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=3172.419, Time=0.44 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 3.106 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4351.431, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4276.093, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4233.262, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4349.432, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4229.904, Time=0.22 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4229.742, Time=0.27 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=4260.152, Time=0.14 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=4231.718, Time=0.36 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4231.716, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4229.996, Time=0.37 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=4249.332, Time=0.19 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=4233.714, Time=0.70 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=4227.745, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4227.908, Time=0.15 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=4258.158, Time=0.09 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=4229.721, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=4229.718, Time=0.30 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=4274.098, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4228.000, Time=0.22 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=4247.339, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=4231.726, Time=0.25 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 4.580 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5370.338, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5277.885, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5222.393, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5368.340, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5216.883, Time=0.20 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5216.642, Time=0.54 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=5255.948, Time=0.28 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=5218.630, Time=0.45 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5218.627, Time=0.36 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5216.870, Time=0.38 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=5241.878, Time=0.22 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=5220.637, Time=0.50 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=5214.649, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5214.890, Time=0.15 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=5253.952, Time=0.10 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=5216.637, Time=0.28 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=5216.634, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=5275.888, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5214.877, Time=0.24 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=5239.884, Time=0.14 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=5218.643, Time=0.27 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 4.870 seconds
#
# SARIMAX RMSE (all folds): 72.3296
# SARIMAX Norm RMSE (all folds): 112%
#
#
# -------------------------------------------
# Model Cross Validation Results:
# -------------------------------------------
#     MAE (Mean Absolute Error = 59.15
#     MSE (Mean Squared Error = 6530.71
#     MAPE (Mean Absolute Percent Error) = 36%
#     RMSE (Root Mean Squared Error) = 80.8128
#     Normalized RMSE (MinMax) = 24%
#     Normalized RMSE (as Std Dev of Actuals)= 132%
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6405.701, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=6283.353, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=6214.714, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6403.703, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=6209.392, Time=0.24 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=6207.469, Time=0.33 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=6258.232, Time=0.08 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=6209.361, Time=0.81 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=6209.321, Time=0.37 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=6208.221, Time=0.47 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=6238.486, Time=0.26 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=6211.315, Time=0.55 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=6205.519, Time=0.22 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=6207.438, Time=0.15 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=6256.248, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=6207.410, Time=0.31 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=6207.370, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=6281.361, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=6206.273, Time=0.26 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=6236.508, Time=0.15 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=6209.364, Time=0.33 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 5.259 seconds
# Refitting data with previously found best parameters
#     Best aic metric = 6191.9
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:         Arrivals(Qtls)   No. Observations:                  615
# Model:               SARIMAX(2, 1, 1)   Log Likelihood               -3089.939
# Date:                Mon, 02 May 2022   AIC                           6191.879
# Time:                        17:36:40   BIC                           6218.379
# Sample:                    04-25-2017   HQIC                          6202.186
#                          - 12-30-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0762      0.576      0.132      0.895      -1.052       1.205
# drift         -0.0003      0.002     -0.158      0.875      -0.004       0.003
# ar.L1          0.2112      0.043      4.879      0.000       0.126       0.296
# ar.L2          0.0945      0.040      2.375      0.018       0.017       0.172
# ma.L1         -0.8354      0.031    -26.716      0.000      -0.897      -0.774
# sigma2      1466.6381     43.341     33.840      0.000    1381.692    1551.584
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1365.03
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.49   Skew:                            -0.49
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#
# ==================================================
# Building VAR Model - best suited for small datasets < 1000 rows and < 10 columns
# ==================================================
#
#
#
# No VAR model created since no explanatory variables given in data set
#
#
# ==================================================
# Building ML Model
# ==================================================
#
#
#
# Creating 2 lagged variables for Machine Learning model...
#     You have set lag = 3 in auto_timeseries setup to feed prior targets. You cannot set lags > 10 ...
# ### Be careful setting dask_xgboost_flag to True since dask is unstable and doesn't work sometime's ###
#
# ########### Single-Label Regression Model Tuning and Training Started ####
#
# Fitting ML model
#     11 variables used in training ML model = ['Arrivals(Qtls)(t-1)', 'index_hour', 'index_minute', 'index_dayofweek', 'index_quarter', 'index_month', 'index_year', 'index_dayofyear', 'index_dayofmonth', 'index_weekofyear', 'index_weekend']
#     Forecast period too high. Cutting by 90% to 61 to enable cross_validation
#
# Running Cross Validation using XGBoost model..
#     Max. iterations using expanding window cross validation = 2
# train fold shape (552, 11), test fold shape = (62, 11)
# ### Number of booster rounds = 250 for XGBoost which can be set during setup ####
#     Hyper Param Tuning XGBoost with CPU parameters. This will take time. Please be patient...
# Cross-validated Score = 41.425 in num rounds = 249
# Time taken for Hyper Param tuning of XGBoost (in minutes) = 0.1
# Top 10 features:
# ['index_year', 'Arrivals(Qtls)(t-1)', 'index_weekofyear', 'index_dayofyear', 'index_quarter', 'index_month', 'index_dayofmonth', 'index_dayofweek', 'index_weekend']
#     Time taken for training XGBoost on entire train data (in minutes) = 0.1
# Returning the following:
#     Model = <xgboost.core.Booster object at 0x00000198CD513F40>
#     Scaler = Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('simpleimputer',
#                                                   SimpleImputer(),
#                                                   ['Arrivals(Qtls)(t-1)',
#                                                    'index_hour', 'index_minute',
#                                                    'index_dayofweek',
#                                                    'index_quarter',
#                                                    'index_month', 'index_year',
#                                                    'index_dayofyear',
#                                                    'index_dayofmonth',
#                                                    'index_weekofyear',
#                                                    'index_weekend'])])),
#                 ('maxabsscaler', MaxAbsScaler())])
#     (3) sample predictions:[167.99142 166.03285 164.6804 ]
# XGBoost model tuning completed
# Target = Arrivals(Qtls)...CV results:
#     RMSE = 32.02
#     Std Deviation of actuals = 26.90
#     Normalized RMSE (as pct of std dev) = 119%
#
# Fitting model on entire train set. Please be patient...
#     Time taken to train model (in seconds) = 1
#
# Best Model is: ML
#     Best Model (Mean CV) Score: 32.02
#
#
# --------------------------------------------------
# Total time taken: 56 seconds.
# --------------------------------------------------
#
#
# Leaderboard with best model on top of list:
#             name        rmse
# 3            ML   32.017646
# 1  auto_SARIMAX   72.329602
# 0       Prophet  122.883899
# 2           VAR         inf

# %%
future_pred = model.predict(testdata = test, model = 'best')
# Out:
# Predicting using test dataframe shape = (365, 2) for ML model
# For large datasets: ML predictions will take time since it has to predict each row and use that for future predictions...
#     Using given input: pandas dataframe...
#     Alert: No strf_time_format given for index. Provide strf_time format during "setup" for better results.
# ML predictions completed

# %%
future_pred.values
# Out:
# array([[171.89401245,          nan,          nan,          nan],
#        [183.04367065,          nan,          nan,          nan],
#        [176.19618225,          nan,          nan,          nan],
#        ...,
#        [164.1230011 ,          nan,          nan,          nan],
#        [172.11463928,          nan,          nan,          nan],
#        [178.88148499,          nan,          nan,          nan]])

# %%
future_pred.head(2)
# Out:
#             Arrivals(Qtls)  mean_se  mean_ci_lower  mean_ci_upper
# index
# 2018-12-31      171.894012      NaN            NaN            NaN
# 2019-01-01      183.043671      NaN            NaN            NaN

# %%
test['ypred']=future_pred['Arrivals(Qtls)'].values

# %%
test.head(10)
# Out:
#        index  Arrivals(Qtls)       ypred
# 0 2018-12-31      187.000000  171.894012
# 1 2019-01-01      142.000000  183.043671
# 2 2019-01-02      122.000000  176.196182
# 3 2019-01-03      177.000000  166.760315
# 4 2019-01-04      175.888889  153.990112
# 5 2019-01-05      180.941176  159.419754
# 6 2019-01-06      181.000000  210.717636
# 7 2019-01-07      180.266667  243.671814
# 8 2019-01-08      178.000000  259.744812
# 9 2019-01-09      175.384615  265.737946

# %% [markdown]
# https://www.youtube.com/watch?v=YVQzFCPkgt4

# %%
test['Arrivals(Qtls)'].plot(figsize=(10,6))
test['ypred'].plot(figsize=(10,6))
plt.show()

# %%
train.set_index('index', inplace = True)
train.head(2)
# Out:
#             Arrivals(Qtls)
# index
# 2017-04-25           232.0
# 2017-04-26           232.0

# %%
plt.plot(train['Arrivals(Qtls)'], label='Train')
plt.show()

# %%
test.set_index('index', inplace = True)
test.head(2)
# Out:
#             Arrivals(Qtls)       ypred
# index
# 2018-12-31           187.0  171.894012
# 2019-01-01           142.0  183.043671

# %%
plt.plot(train['Arrivals(Qtls)'], label='Train')
plt.plot(test['Arrivals(Qtls)'], label='Test')
plt.plot(test['ypred'], label='Prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['Arrivals(Qtls)'],test['ypred']))
print("ROOT MEAN SQAURED ERROR (RMSE) :",rmse)
# Out:
# ROOT MEAN SQAURED ERROR (RMSE) : 64.56266445221277

# %% [markdown]
# #### BACK FILL

# %%
df2 = pd.DataFrame(columns=['Arrivals(Qtls)'],data=df, index = dt)
df2.head(10)
# Out:
#             Arrivals(Qtls)
# 2017-04-25           232.0
# 2017-04-26             NaN
# 2017-04-27             NaN
# 2017-04-28           222.0
# 2017-04-29           200.0
# 2017-04-30             NaN
# 2017-05-01           217.0
# 2017-05-02           125.0
# 2017-05-03           267.0
# 2017-05-04             NaN

# %%
df2.isnull().sum()
# Out:
# Arrivals(Qtls)    232
# dtype: int64

# %%
df2 = df2.fillna(method ='bfill')

# %%
df2.isnull().sum()
# Out:
# Arrivals(Qtls)    0
# dtype: int64

# %%
df2.plot()
plt.show()

# %%
df2.boxplot()
plt.show()

# %%
q1= df2.quantile(0.25)
q3 = df2.quantile(0.75)
qmax= df2.quantile(0.90)
q1,q3,qmax
# Out:
# (Arrivals(Qtls)    131.75
#  Name: 0.25, dtype: float64,
#  Arrivals(Qtls)    210.0
#  Name: 0.75, dtype: float64,
#  Arrivals(Qtls)    255.0
#  Name: 0.9, dtype: float64)

# %%
for i in range(len(df2)):
    if df2['Arrivals(Qtls)'][i] >=1000.0:
        print(df2['Arrivals(Qtls)'][i])
        df2['Arrivals(Qtls)'][i] = qmax
# Out:
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 2017.0

# %%
df2.plot()
plt.show()

# %%
plot_acf(df2, lags =25)
plt.show()

# %%
plot_pacf(df2,lags =25)
plt.show()

# %% [markdown]
# #### The plot for 200 datapoints ...~ 7 months

# %%
plt.figure(figsize=(8,4))
results = seasonal_decompose(df2['Arrivals(Qtls)'].iloc[800:1000])
results.plot();

# %% [markdown]
# #### DICKEY FULLER TEST for STATIONARITY

# %%
observations= df2.values
test_result = adfuller(observations)

# %%
print('ADF Statistic: %f' % test_result[0])
print('p-value: %f' % test_result[1])
print('Critical Values:')
for key, value in test_result[4].items():
	print('\t%s: %.5f' % (key, value))
# Out:
# ADF Statistic: -2.607377
# p-value: 0.091482
# Critical Values:
# 	1%: -3.43714
# 	5%: -2.86454
# 	10%: -2.56837
