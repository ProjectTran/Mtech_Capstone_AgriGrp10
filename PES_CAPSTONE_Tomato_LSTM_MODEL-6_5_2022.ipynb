# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal     import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller

from datetime import datetime,timedelta
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing,Holt
from statsmodels.tsa.stattools         import  pacf
from statsmodels.tsa.stattools         import  acf
from statsmodels.graphics.tsaplots     import  plot_pacf
from statsmodels.graphics.tsaplots     import  plot_acf
from statsmodels.graphics.gofplots     import qqplot
from statsmodels.tsa.arima_model       import  ARMA, ARIMA
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')
from time import time
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from statsmodels.tsa.stattools import pacf
# %matplotlib inline

import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_excel('Sample Commodities_Vegetables_Hyderabad_Market.xls',
                    sheet_name="Tomato",parse_dates =["Date"], index_col ='Date')
df.head(2)
# Out:
#            Variety Name  Arrivals(Qtls)  Maximum  Minimum  Model  \
# Date
# 2017-04-25       Tomato             232      800      600    700
# 2017-04-28       Tomato             222      800      600    700
#
#                 Purchase by
# Date
# 2017-04-25  Private Traders
# 2017-04-28  Private Traders

# %%
df.tail(2)
# Out:
#            Variety Name  Arrivals(Qtls)  Maximum  Minimum  Model  \
# Date
# 2019-12-30       Tomato             227      600      400    500
# 2019-12-31       Tomato             190      800      600    700
#
#                 Purchase by
# Date
# 2019-12-30  Private Traders
# 2019-12-31  Private Traders

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 749 entries, 2017-04-25 to 2019-12-31
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Variety Name    749 non-null    object
#  1   Arrivals(Qtls)  749 non-null    int64
#  2   Maximum         749 non-null    int64
#  3   Minimum         749 non-null    int64
#  4   Model           749 non-null    int64
#  5   Purchase by     749 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 41.0+ KB

# %%
df.isnull().sum()
# Out:
# Variety Name      0
# Arrivals(Qtls)    0
# Maximum           0
# Minimum           0
# Model             0
# Purchase by       0
# dtype: int64

# %%
df.describe()
# Out:
#        Arrivals(Qtls)    Maximum    Minimum      Model
# count        749.0000   749.0000   749.0000   749.0000
# mean         180.2256  1856.1415  1369.6395  1671.6956
# std          104.7997  1492.9038  1370.1417  2237.9556
# min            7.0000    80.0000   100.0000   100.0000
# 25%          130.0000   800.0000   600.0000   700.0000
# 50%          167.0000  1200.0000   800.0000  1100.0000
# 75%          215.0000  2600.0000  2000.0000  2200.0000
# max         2017.0000 20000.0000 22400.0000 44400.0000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
df = df[~df.index.duplicated()]

# %%
dt = pd.date_range(start ='25-04-2017', end ='31-12-2019', freq ='D' )
dt
# Out:
# DatetimeIndex(['2017-04-25', '2017-04-26', '2017-04-27', '2017-04-28',
#                '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#                '2017-05-03', '2017-05-04',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=981, freq='D')

# %%
df1 = pd.DataFrame(columns=['Arrivals(Qtls)'],data=df, index = dt)
df1.head(10)
# Out:
#             Arrivals(Qtls)
# 2017-04-25        232.0000
# 2017-04-26             nan
# 2017-04-27             nan
# 2017-04-28        222.0000
# 2017-04-29        200.0000
# 2017-04-30             nan
# 2017-05-01        217.0000
# 2017-05-02        125.0000
# 2017-05-03        267.0000
# 2017-05-04             nan

# %%
df1.isnull().sum()
# Out:
# Arrivals(Qtls)    232
# dtype: int64

# %%
df1['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
#df1 = df1.fillna(df1.rolling(22,min_periods=1).mean())

# %%
df1 = df1.fillna(df1.rolling(22,min_periods=1).mean())

# %%
df1.isnull().sum()
# Out:
# Arrivals(Qtls)    0
# dtype: int64

# %% [markdown]
# #### the null values are filled after 9 datapoints

# %%
df1.value_counts()
# Out:
# Arrivals(Qtls)
# 150.0000          18
# 190.0000          14
# 162.0000          14
# 175.0000          14
# 157.0000          13
#                   ..
# 178.7143           1
# 178.1429           1
# 178.0000           1
# 176.7000           1
# 7.0000             1
# Length: 351, dtype: int64

# %%
df1['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
q1= df1.quantile(0.25)
q3 = df1.quantile(0.75)
qmax= df1.quantile(0.90)
q1,q3,qmax
# Out:
# (Arrivals(Qtls)   135.0000
#  Name: 0.25, dtype: float64,
#  Arrivals(Qtls)   215.4286
#  Name: 0.75, dtype: float64,
#  Arrivals(Qtls)   260.0000
#  Name: 0.9, dtype: float64)

# %%
#for i in range(len(df)):
  #  if df1['Arrivals(Qtls)'][i] >= 18000:
   #     print(df1['Arrivals(Qtls)'][i])
  #      df1['Arrivals(Qtls)'][i] = qmax

# %%
df1['Arrivals(Qtls)'].plot(figsize=(8,6))
plt.show()

# %%
df1.describe().plot.bar(figsize=(10,5))
plt.show()

# %%
plot_acf(df1, lags =20)
plt.show()

# %%
plot_pacf(df1,lags =20)
plt.show()

# %% [markdown]
# Statistical Normality Test
# There are several statistical tests that we can use to quantify whether our data looks as though it was drawn from a Gaussian distribution. ## And we will use D’Agostino’s K^2 Test.
#
# In the SciPy implementation of the test, we will interpret the p value as follows.
#
# p <= alpha: reject H0, not normal.
# p > alpha: fail to reject H0, normal.

# %%
stat, p = stats.normaltest(df['Arrivals(Qtls)'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Data looks Gaussian (fail to reject H0)')
else:
    print('Data does not look Gaussian (reject H0)')
# Out:
# Statistics=1180.531, p=0.000
# Data does not look Gaussian (reject H0)

# %% [markdown]
# #### The plot for 200 datapoints ...~ 7 months

# %%
plt.figure(figsize=(8,4))
results = seasonal_decompose(df1['Arrivals(Qtls)'].iloc[800:1000])
results.plot()
plt.show();

# %% [markdown]
# #### DICKEY FULLER TEST for STATIONARITY

# %%
observations= df1.values
test_result = adfuller(observations)

# %%
print('ADF Statistic: %f' % test_result[0])
print('p-value: %f' % test_result[1])
print('Critical Values:')
for key, value in test_result[4].items():
	print('\t%s: %.5f' % (key, value))
# Out:
# ADF Statistic: -4.280582
# p-value: 0.000480
# Critical Values:
# 	1%: -3.43712
# 	5%: -2.86453
# 	10%: -2.56836

# %% [markdown]
# #### LSTM model

# %%
dataset = df1['Arrivals(Qtls)'].values #numpy.ndarray
dataset = dataset.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
# reshape into X=t and Y=t+1
look_back = 15
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# %% [markdown]
# #### MODEL ARCHITECTURE

# %%
X_train.shape
# Out:
# (768, 15)

# %%
Y_train.shape
# Out:
# (768,)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
X_train.shape
# Out:
# (768, 1, 15)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 100)               46400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 46,501
# Trainable params: 46,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(X_train, Y_train, epochs=500, batch_size=8, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)
# Out:
# Train on 768 samples, validate on 181 samples
# Epoch 1/500
# 768/768 [==============================] - 1s 844us/step - loss: 0.0025 - val_loss: 3.9254e-04
# Epoch 2/500
# 768/768 [==============================] - 0s 295us/step - loss: 0.0022 - val_loss: 3.8957e-04
# Epoch 3/500
# 768/768 [==============================] - ETA: 0s - loss: 0.0024 - 0s 321us/step - loss: 0.0022 - val_loss: 4.4697e-04
# Epoch 4/500
# 768/768 [==============================] - 0s 319us/step - loss: 0.0021 - val_loss: 4.0763e-04
# Epoch 5/500
# 768/768 [==============================] - 0s 372us/step - loss: 0.0022 - val_loss: 3.9572e-04
# Epoch 6/500
# 768/768 [==============================] - 0s 404us/step - loss: 0.0022 - val_loss: 4.0260e-04
# Epoch 7/500
# 768/768 [==============================] - 0s 401us/step - loss: 0.0021 - val_loss: 3.7123e-04
# Epoch 8/500
# 768/768 [==============================] - 0s 363us/step - loss: 0.0021 - val_loss: 3.8428e-04
# Epoch 9/500
# 768/768 [==============================] - 0s 336us/step - loss: 0.0021 - val_loss: 3.7518e-04
# Epoch 10/500
# 768/768 [==============================] - 0s 331us/step - loss: 0.0021 - val_loss: 3.6587e-04
# Epoch 11/500
# 768/768 [==============================] - 0s 389us/step - loss: 0.0021 - val_loss: 3.5958e-04
# Epoch 12/500
# 768/768 [==============================] - 0s 466us/step - loss: 0.0021 - val_loss: 3.5407e-04
# Epoch 13/500
# 768/768 [==============================] - 0s 417us/step - loss: 0.0021 - val_loss: 3.2539e-04
# Epoch 14/500
# 768/768 [==============================] - 0s 388us/step - loss: 0.0021 - val_loss: 3.3032e-04
# Epoch 15/500
# 768/768 [==============================] - 0s 341us/step - loss: 0.0021 - val_loss: 3.4708e-04
# Epoch 16/500
# 768/768 [==============================] - 0s 391us/step - loss: 0.0021 - val_loss: 3.3811e-04
# Epoch 17/500
# 768/768 [==============================] - 0s 392us/step - loss: 0.0021 - val_loss: 3.2272e-04
# Epoch 18/500
# 768/768 [==============================] - 0s 387us/step - loss: 0.0021 - val_loss: 3.3916e-04
# Epoch 19/500
# 768/768 [==============================] - 0s 406us/step - loss: 0.0021 - val_loss: 3.2624e-04
# Epoch 20/500
# 768/768 [==============================] - 0s 340us/step - loss: 0.0021 - val_loss: 3.0294e-04
# Epoch 21/500
# 768/768 [==============================] - 0s 331us/step - loss: 0.0021 - val_loss: 3.0864e-04
# Epoch 22/500
# 768/768 [==============================] - 0s 322us/step - loss: 0.0020 - val_loss: 3.2390e-04
# Epoch 23/500
# 768/768 [==============================] - 0s 337us/step - loss: 0.0021 - val_loss: 2.9888e-04
# Epoch 24/500
# 768/768 [==============================] - 0s 336us/step - loss: 0.0021 - val_loss: 3.0577e-04
# Epoch 25/500
# 768/768 [==============================] - 0s 322us/step - loss: 0.0021 - val_loss: 3.0717e-04
# Epoch 26/500
# 768/768 [==============================] - 0s 333us/step - loss: 0.0021 - val_loss: 2.8980e-04
# Epoch 27/500
# 768/768 [==============================] - 0s 397us/step - loss: 0.0020 - val_loss: 3.0880e-04
# Epoch 28/500
# 768/768 [==============================] - 0s 388us/step - loss: 0.0020 - val_loss: 2.8410e-04
# Epoch 29/500
# 768/768 [==============================] - 0s 396us/step - loss: 0.0020 - val_loss: 3.0098e-04
# Epoch 30/500
# 768/768 [==============================] - 0s 467us/step - loss: 0.0020 - val_loss: 2.9290e-04
# Epoch 31/500
# 768/768 [==============================] - 0s 410us/step - loss: 0.0020 - val_loss: 2.9498e-04
# Epoch 32/500
# 768/768 [==============================] - 0s 355us/step - loss: 0.0020 - val_loss: 2.9712e-04
# Epoch 33/500
# 768/768 [==============================] - 0s 417us/step - loss: 0.0020 - val_loss: 2.9135e-04
# Epoch 34/500
# 768/768 [==============================] - 0s 421us/step - loss: 0.0020 - val_loss: 2.7320e-04
# Epoch 35/500
# 768/768 [==============================] - 0s 408us/step - loss: 0.0020 - val_loss: 2.8857e-04
# Epoch 36/500
# 768/768 [==============================] - 0s 397us/step - loss: 0.0020 - val_loss: 2.8013e-04
# Epoch 37/500
# 768/768 [==============================] - 0s 367us/step - loss: 0.0020 - val_loss: 2.7675e-04
# Epoch 38/500
# 768/768 [==============================] - 0s 475us/step - loss: 0.0020 - val_loss: 2.6722e-04
# Epoch 39/500
# 768/768 [==============================] - 0s 504us/step - loss: 0.0020 - val_loss: 2.8867e-04
# Epoch 40/500
# 768/768 [==============================] - 0s 495us/step - loss: 0.0019 - val_loss: 2.5475e-04
# Epoch 41/500
# 768/768 [==============================] - 0s 479us/step - loss: 0.0020 - val_loss: 2.8084e-04
# Epoch 42/500
# 768/768 [==============================] - 0s 424us/step - loss: 0.0020 - val_loss: 2.6162e-04
# Epoch 43/500
# 768/768 [==============================] - 0s 426us/step - loss: 0.0020 - val_loss: 2.7213e-04
# Epoch 44/500
# 768/768 [==============================] - 0s 428us/step - loss: 0.0020 - val_loss: 2.7295e-04
# Epoch 45/500
# 768/768 [==============================] - 0s 404us/step - loss: 0.0019 - val_loss: 2.6182e-04
# Epoch 46/500
# 768/768 [==============================] - 0s 395us/step - loss: 0.0020 - val_loss: 2.5973e-04
# Epoch 47/500
# 768/768 [==============================] - 0s 414us/step - loss: 0.0020 - val_loss: 2.5531e-04
# Epoch 48/500
# 768/768 [==============================] - 0s 402us/step - loss: 0.0019 - val_loss: 2.5720e-04
# Epoch 49/500
# 768/768 [==============================] - 0s 413us/step - loss: 0.0019 - val_loss: 2.5626e-04
# Epoch 50/500
# 768/768 [==============================] - 0s 443us/step - loss: 0.0020 - val_loss: 2.6514e-04

# %%
# make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])

print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 35.88997287721733
# Train Root Mean Squared Error: 90.48222991583353
# Test Mean Absolute Error: 24.309230837571487
# Test Root Mean Squared Error: 32.72877611631321

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
aa=[x for x in range(181)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('Arrivals in Quintals', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
# print(df['Arrivals(Qtls)'].describe())
sns.distplot(df1['Arrivals(Qtls)']);
print( 'Kurtosis of normal distribution: {}'.format(stats.kurtosis(df1['Arrivals(Qtls)'])))
print( 'Skewness of normal distribution: {}'.format(stats.skew(df1['Arrivals(Qtls)'])))
# Out:
# Kurtosis of normal distribution: 154.8051305450214
# Skewness of normal distribution: 9.271654120714722

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
df1['Arrivals(Qtls)'].hist(bins=50)
plt.title('Arrivals in Quintals')

plt.subplot(1,2,2)
stats.probplot(df1['Arrivals(Qtls)'], plot=plt);
df1.describe().T
# Out:
#                   count     mean     std    min      25%      50%      75%  \
# Arrivals(Qtls) 981.0000 180.7779 95.3210 7.0000 135.0000 172.0000 215.4286
#
#                      max
# Arrivals(Qtls) 2017.0000

# %%
fig = plt.figure(figsize=(18,16))
fig.subplots_adjust(hspace=.4)
ax1 = fig.add_subplot(5,1,1)
ax1.plot(df1['Arrivals(Qtls)'].resample('D').mean(),linewidth=1)
ax1.set_title('Mean Yeild resampled over day')
ax1.tick_params(axis='both', which='major')

ax2 = fig.add_subplot(5,1,2, sharex=ax1)
ax2.plot(df1['Arrivals(Qtls)'].resample('W').mean(),linewidth=1)
ax2.set_title('Mean Yeild resampled over week')
ax2.tick_params(axis='both', which='major')

ax3 = fig.add_subplot(5,1,3, sharex=ax1)
ax3.plot(df1['Arrivals(Qtls)'].resample('M').mean(),linewidth=1)
ax3.set_title('Mean Yeild resampled over month')
ax3.tick_params(axis='both', which='major')

ax4  = fig.add_subplot(5,1,4, sharex=ax1)
ax4.plot(df1['Arrivals(Qtls)'].resample('Q').mean(),linewidth=1)
ax4.set_title('Mean Yeild resampled over quarter')
ax4.tick_params(axis='both', which='major')

ax5  = fig.add_subplot(5,1,5, sharex=ax1)
ax5.plot(df1['Arrivals(Qtls)'].resample('A').mean(),linewidth=1)
ax5.set_title('Mean Yeild resampled over year')
ax5.tick_params(axis='both', which='major');
